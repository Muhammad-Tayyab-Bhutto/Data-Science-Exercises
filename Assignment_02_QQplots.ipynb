# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad-Tayyab-Bhutto/Data-Science-Exercises/blob/main/Assignment_02_QQplots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ####Assignment #02
# This is the second assignment for the assessment of Data Science course that is being taught in Fall 2023 at the department of Computer Science, Sukkur IBA University.
#
# Attached with this assignment is a dataset of 13 juices. Each column in the dataset contains the PH level of a juice of different type. Your task is to use these 13 columns and create frequency table and histogram plot for each juice to see how data is distribution. The final task is to use QQplots, find and interpret among which of blew distribution the data fits. It is also possible the data might not get fit in any of the below mentioned distributions.
# * Normal distribution
# * Binomial distribution
# * Chi square distribution
# * Poisson distribution
# * Exponential distribution
# * Students’ t distribution

# %%
# You code should be here
# Any interpretation can be placed in comments also

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from statsmodels.graphics.gofplots import qqplot

# %%
data = pd.read_excel('/content/drive/MyDrive/DataScience /DataSets/Juices.xlt')

# %%
data.head(20)
# Out:
#     Juice01  Juice02  Juice03  Juice04  Juice05  Juice06  Juice07  Juice08  \
# 0     14.23     1.71     2.43     15.6      127     2.80     3.06     0.28
# 1     13.20     1.78     2.14     11.2      100     2.65     2.76     0.26
# 2     13.16     2.36     2.67     18.6      101     2.80     3.24     0.30
# 3     14.37     1.95     2.50     16.8      113     3.85     3.49     0.24
# 4     13.24     2.59     2.87     21.0      118     2.80     2.69     0.39
# 5     14.20     1.76     2.45     15.2      112     3.27     3.39     0.34
# 6     14.39     1.87     2.45     14.6       96     2.50     2.52     0.30
# 7     14.06     2.15     2.61     17.6      121     2.60     2.51     0.31
# 8     14.83     1.64     2.17     14.0       97     2.80     2.98     0.29
# 9     13.86     1.35     2.27     16.0       98     2.98     3.15     0.22
# 10    14.10     2.16     2.30     18.0      105     2.95     3.32     0.22
# ...

# %%
# ================= Frequency Table =====================
for column in data.columns:
    # Creating a Frequency Table = (Counting the number of occurances of each unique value in column and sorting them)
    frequency_table = data[column].value_counts().sort_index()
    print(f"\nFrequency Table for {column}:\n")
    print(frequency_table)

    # ================Histogram Plot=====================
    plt.figure(figsize=(10, 6))
    # (kde=True) parameter adds a kernel density estimate to plot for a smoother representation
    sns.histplot(data[column], kde=True)
    plt.title(f'Histogram for {column}')
    plt.xlabel('PH Level')
    plt.ylabel('Frequency')
    plt.show()

    # ================QQ ( Quantile-Quantile ) Plot================================
    #  QQ plot is used to assess if a dataset follows a particular theoretical distribution (in our dataset case we have normal distribution).
    qqplot(data[column], line='s')
    plt.title(f'QQ Plot for {column}')
    plt.show()

    # Fit the data to different distributions and printing goodness-of-fit test results
    distributions = ['norm', 'expon', 't', 'poisson']
    for distribution in distributions:
        if distribution == 'norm':
            params = stats.norm.fit(data[column])
        elif distribution == 'expon':
            params = stats.expon.fit(data[column])
        elif distribution == 't':
            params = stats.t.fit(data[column])
        elif distribution == 'poisson':
            params = (data[column].mean(),)

        stat, p_value = stats.kstest(data[column], distribution, args=params)
        print(f'K-S test for {column} and {distribution}: p-value = {p_value}')
# Out:
# Frequency Table for Juice01:
#
# 11.03    1
# 11.41    1
# 11.45    1
# 11.46    1
# 11.56    1
#         ..
# 14.37    1
# 14.38    2
# 14.39    1
# 14.75    1
# 14.83    1
# Name: Juice01, Length: 126, dtype: int64
# K-S test for Juice01 and norm: p-value = 0.35686679600830495
# K-S test for Juice01 and expon: p-value = 5.146870825210944e-13
# K-S test for Juice01 and t: p-value = 0.35666484940618337
# K-S test for Juice01 and poisson: p-value = 9.961630192098273e-21
#
# Frequency Table for Juice02:
#
# 0.74    1
# 0.89    1
# 0.90    1
# 0.92    1
# 0.94    2
#        ..
# 5.04    1
# 5.19    1
# 5.51    1
# 5.65    1
# 5.80    1
# Name: Juice02, Length: 133, dtype: int64
# K-S test for Juice02 and norm: p-value = 3.3428804073338534e-06
# K-S test for Juice02 and expon: p-value = 2.630241425858685e-06
# K-S test for Juice02 and t: p-value = 4.322857407185159e-05
# K-S test for Juice02 and poisson: p-value = 1.2755573673776867e-12
#
# Frequency Table for Juice03:
#
# 1.36    1
# ...

# %% [markdown]
# Your text interpretation of the best fit here
